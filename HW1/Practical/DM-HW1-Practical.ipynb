# %% [markdown]
# <h1 align=center style="line-height:300%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# سری اول تمارین عملی درس داده کاوی
# </font>
# </h1>
# <h3 align=center style="line-height:100%;font-family:vazir;color:#0099cc">
# استاد درس: دکتر مریم امیر مزلقانی
# </h3>
# <h5 align=center style="font-size: 20px;line-height:100%;font-family:vazir;color:#0099cc">
# طراح تمرین عملی: پوریا جمیع
# </h5>
# <p align=center style="font-size: 16;line-height:100%;font-family:vazir;color:#0099cc">
#     <a href="mailto:Aut.DataMining.Fall@gmail.com">Aut.DataMining.Fall@gmail.com</a>
# </p>

# %% [markdown]
# <div dir="rtl">
# <p align=right style="font-size: 16;line-height:100%;font-family:vazir;color:yellow">
# لطفا خواسته های تمرین را در بخش خودش انجام دهید.
# </p>
#
# </div>

# %% [markdown]
# <div dir="rtl">
# <h3 align=right style="font-size: 16;line-height:100%;font-family:vazir;color:white">
# خواندن کتابخانه ها
# </h3>
# </div>

# %%
# TO-DO
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <div dir="rtl">
# <h3 align=right style="font-size: 16;line-height:100%;font-family:vazir;color:white">
# دریافت مجموعه داده
# </h3>
# </div>

# %%
# load data
df = pd.read_excel("worldcities.xlsx")
print(df.shape)
df.head(20)
# Out:
# (44667, 11)
#          ville ville_ascii      lat       lng         pays iso2 iso3  \
# 0     A Coruña    A Coruna  43.3667   -8.3833        Spain   ES  ESP
# 1     A Yun Pa    A Yun Pa  13.3939  108.4408      Vietnam   VN  VNM
# 2     Aabenraa    Aabenraa  55.0444    9.4181      Denmark   DK  DNK
# 3       Aachen      Aachen  50.7756    6.0836      Germany   DE  DEU
# 4       Aadorf      Aadorf  47.4939    8.8975  Switzerland   CH  CHE
# 5      Aalborg     Aalborg  57.0500    9.9167      Denmark   DK  DNK
# 6        Aalen       Aalen  48.8333   10.1000      Germany   DE  DEU
# 7        Aaley       Aaley  33.8000   35.6000      Lebanon   LB  LBN
# 8     Aalsmeer    Aalsmeer  52.2667    4.7500  Netherlands   NL  NLD
# 9        Aalst       Aalst  50.9383    4.0392      Belgium   BE  BEL
# 10      Aalten      Aalten  51.9333    6.5833  Netherlands   NL  NLD
# 11   Äänekoski   Aanekoski  62.6000   25.7250      Finland   FI  FIN
# 12       Aarau       Aarau  47.4000    8.0500  Switzerland   CH  CHE
# 13      Aarhus      Aarhus  56.1572   10.2107      Denmark   DK  DNK
# 14      Aarsâl      Aarsal  34.1794   36.4208      Lebanon   LB  LBN
# 15    Aarschot    Aarschot  50.9842    4.8333      Belgium   BE  BEL
# 16  Aartselaar  Aartselaar  51.1333    4.3833      Belgium   BE  BEL
# 17     Aasiaat     Aasiaat  68.7097  -52.8694    Greenland   GL  GRL
# 18   Āb Pakhsh   Ab Pakhsh  29.3606   51.0683         Iran   IR  IRN
# 19         Aba         Aba   5.1167    7.3667      Nigeria   NG  NGA
#
#                  admin_nom capital  population            id
# 0                  Galicia   minor    245468.0  1.724417e+09
# 1                  Gia Lai   minor     53720.0  1.704946e+09
# 2               Syddanmark   minor     16401.0  1.208000e+09
# 3   North Rhine-Westphalia   minor    249070.0  1.276806e+09
# 4                  Thurgau     NaN      9036.0  1.756023e+09
# 5              Nordjylland   admin    143598.0  1.208789e+09
# 6        Baden-Württemberg   minor     68361.0  1.276758e+09
# 7               Mont-Liban   minor    130000.0  1.422056e+09
# 8            Noord-Holland   minor     31991.0  1.528900e+09
# 9                 Flanders   minor     88854.0  1.056696e+09
# 10              Gelderland   minor     27120.0  1.528326e+09
# 11             Keski-Suomi   minor     19919.0  1.246710e+09
# 12                  Aargau   admin     21503.0  1.756722e+09
# 13             Midtjylland   minor    285273.0  1.208841e+09
# 14          Baalbek-Hermel     NaN     50000.0  1.422613e+09
# 15                Flanders     NaN     29965.0  1.056740e+09
# 16                Flanders     NaN     14427.0  1.056119e+09
# 17              Qeqertalik   admin      3069.0  1.304195e+09
# 18                 Būshehr     NaN     18913.0  1.364463e+09
# 19                    Abia   minor   1530000.0  1.566262e+09

# %% [markdown]
# <div dir="rtl">
# <h3 align=right style="font-size: 16;line-height:100%;font-family:vazir;color:white">
# حذف و تغییر نام ستون ها
# </h3>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# ستون‌های
# <code>id</code>،
# <code>‌capital</code>،
# <code>ville_ascii</code>
# و
# <code>admin_nom</code>
#  را از دیتافریم حذف نمایید.
# سپس نام ستون‌های
# <code>ville</code>
# و
# <code>pays</code>
#  که به زبان فرانسوی نامگذاری شده‌اند را به ترتیب به
# <code>city</code>
# و
# <code>country</code>
# تغییر دهید.
# </font>
# </p>
# </div>

# %%
# drop and rename
df = df.drop(columns=['ville_ascii', 'admin_nom', 'id', 'capital'])
df = df.rename(columns={'ville': 'city', 'pays': 'country'})
df
# Out:
#              city      lat       lng      country iso2 iso3  population
# 0        A Coruña  43.3667   -8.3833        Spain   ES  ESP    245468.0
# 1        A Yun Pa  13.3939  108.4408      Vietnam   VN  VNM     53720.0
# 2        Aabenraa  55.0444    9.4181      Denmark   DK  DNK     16401.0
# 3          Aachen  50.7756    6.0836      Germany   DE  DEU    249070.0
# 4          Aadorf  47.4939    8.8975  Switzerland   CH  CHE      9036.0
# ...           ...      ...       ...          ...  ...  ...         ...
# 44662     Żychlin  52.2453   19.6236       Poland   PL  POL      9021.0
# 44663    Żyrardów  52.0500   20.4333       Poland   PL  POL     39374.0
# 44664    Zyryanka  65.7360  150.8900       Russia   RU  RUS      3627.0
# 44665  Zyryanovsk  49.7453   84.2548   Kazakhstan   KZ  KAZ     49658.0
# 44666      Żywiec  49.6892   19.2058       Poland   PL  POL     30334.0
#
# [44667 rows x 7 columns]

# %% [markdown]
# <div dir="rtl">
# <h3 align=right style="font-size: 16;line-height:100%;font-family:vazir;color:white">
# فیلتر کردن داده ها
# </h3>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# شهر‌های با جمعیت اکیدا کمتر از ۱ میلیون نفر  را از دیتافریم حذف کرده و سپس نوع داده‌های ستون
# <code>population</code>
#  را از
#  <code>float</code>
#   به
#   <code>int32</code>
#    تبدیل نمایید.
# </p>
# </div>

# %%
# filter data
df = df[df['population'] >= 1e6]
df
# Out:
#             city      lat       lng               country iso2 iso3  \
# 19           Aba   5.1167    7.3667               Nigeria   NG  NGA
# 83       Abidjan   5.3167   -4.0333         Côte d'Ivoire   CI  CIV
# 121    Abu Dhabi  24.4667   54.3667  United Arab Emirates   AE  ARE
# 131        Abuja   9.0667    7.4833               Nigeria   NG  NGA
# 169        Accra   5.5500   -0.2000                 Ghana   GH  GHA
# ...          ...      ...       ...                   ...  ...  ...
# 44496  Zhumadian  32.9773  114.0253                 China   CN  CHN
# 44506    Zhuzhou      NaN  113.1469                 China   CN  CHN
# 44511       Zibo  36.7831  118.0497                 China   CN  CHN
# 44517     Zigong  29.3498  104.7645                 China   CN  CHN
# 44629      Zunyi  27.7050  106.9336                 China   CN  CHN
#
#        population
# 19      1530000.0
# 83      4980000.0
# 121     1483000.0
# 131     3770000.0
# 169     2388000.0
# ...           ...
# 44496   7231234.0
# 44506   4020800.0
# 44511   2631647.0
# 44517   2678899.0
# 44629   6606675.0
#
# [776 rows x 7 columns]

# %%
# change type population
df['population'] = df['population'].astype('int32')
df
# Out:
# C:\Users\98912\AppData\Local\Temp\ipykernel_24368\2018149386.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['population'] = df['population'].astype('int32')
#             city      lat       lng               country iso2 iso3  \
# 19           Aba   5.1167    7.3667               Nigeria   NG  NGA
# 83       Abidjan   5.3167   -4.0333         Côte d'Ivoire   CI  CIV
# 121    Abu Dhabi  24.4667   54.3667  United Arab Emirates   AE  ARE
# 131        Abuja   9.0667    7.4833               Nigeria   NG  NGA
# 169        Accra   5.5500   -0.2000                 Ghana   GH  GHA
# ...          ...      ...       ...                   ...  ...  ...
# 44496  Zhumadian  32.9773  114.0253                 China   CN  CHN
# 44506    Zhuzhou      NaN  113.1469                 China   CN  CHN
# 44511       Zibo  36.7831  118.0497                 China   CN  CHN
# 44517     Zigong  29.3498  104.7645                 China   CN  CHN
# 44629      Zunyi  27.7050  106.9336                 China   CN  CHN
#
#        population
# 19        1530000
# 83        4980000
# 121       1483000
# 131       3770000
# 169       2388000
# ...           ...
# 44496     7231234
# 44506     4020800
# 44511     2631647
# 44517     2678899
# 44629     6606675
#
# [776 rows x 7 columns]

# %%
df = df.reset_index(drop=True)
df
# Out:
#           city      lat       lng               country iso2 iso3  population
# 0          Aba   5.1167    7.3667               Nigeria   NG  NGA     1530000
# 1      Abidjan   5.3167   -4.0333         Côte d'Ivoire   CI  CIV     4980000
# 2    Abu Dhabi  24.4667   54.3667  United Arab Emirates   AE  ARE     1483000
# 3        Abuja   9.0667    7.4833               Nigeria   NG  NGA     3770000
# 4        Accra   5.5500   -0.2000                 Ghana   GH  GHA     2388000
# ..         ...      ...       ...                   ...  ...  ...         ...
# 771  Zhumadian  32.9773  114.0253                 China   CN  CHN     7231234
# 772    Zhuzhou      NaN  113.1469                 China   CN  CHN     4020800
# 773       Zibo  36.7831  118.0497                 China   CN  CHN     2631647
# 774     Zigong  29.3498  104.7645                 China   CN  CHN     2678899
# 775      Zunyi  27.7050  106.9336                 China   CN  CHN     6606675
#
# [776 rows x 7 columns]

# %% [markdown]
# <div dir="rtl">
# <h3 align=right style="font-size: 16;line-height:100%;font-family:vazir;color:white">
# کار با داده های تکراری و گم شده
# </h3>
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# نخست ردیف‌های تکراری دیتافریم و سپس ردیف‌هایی که بیش از یک مورد (۲ مورد و بیش‌تر) از اطلاعات آن‌ها گم‌شده است را از دیتافریم حذف نمایید.
# </p>
# </div>

# %%
# remove duplicated and missed values

# Remove duplicate rows
df = df.drop_duplicates()

# Remove rows with more than one item missing
df = df.dropna(axis=0, thresh=len(df.columns)-1)

df
# Out:
#           city      lat       lng               country iso2 iso3  population
# 0          Aba   5.1167    7.3667               Nigeria   NG  NGA     1530000
# 1      Abidjan   5.3167   -4.0333         Côte d'Ivoire   CI  CIV     4980000
# 2    Abu Dhabi  24.4667   54.3667  United Arab Emirates   AE  ARE     1483000
# 3        Abuja   9.0667    7.4833               Nigeria   NG  NGA     3770000
# 4        Accra   5.5500   -0.2000                 Ghana   GH  GHA     2388000
# ..         ...      ...       ...                   ...  ...  ...         ...
# 771  Zhumadian  32.9773  114.0253                 China   CN  CHN     7231234
# 772    Zhuzhou      NaN  113.1469                 China   CN  CHN     4020800
# 773       Zibo  36.7831  118.0497                 China   CN  CHN     2631647
# 774     Zigong  29.3498  104.7645                 China   CN  CHN     2678899
# 775      Zunyi  27.7050  106.9336                 China   CN  CHN     6606675
#
# [767 rows x 7 columns]

# %% [markdown]
# <div dir="rtl">
# <h3 align=right style="font-size: 16;line-height:100%;font-family:vazir;color:white">
# پر کردن داده های گم‌شده
# </h3>
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# برای مقادیر گم شده در ستون های
# <code>lat</code>
# و
# <code>lng</code>
# ،
# میانگین همان ستون را در
# <ins><strong>همان کشور</strong></ins>
# پر کنید
# </p>
# </div>

# %%
invalid_lat = df.loc[pd.isna(df['lat']), :].index
invalid_lng = df.loc[pd.isna(df['lng']), :].index
print(invalid_lat)
print(invalid_lng)
# Out:
# Int64Index([537, 772], dtype='int64')
# Int64Index([724], dtype='int64')

# %%
print(df.loc[537], '\n\n', df.loc[772], '\n\n', df.loc[724])
# Out:
# city          Rio de Janeiro
# lat                      NaN
# lng                 -43.2056
# country               Brazil
# iso2                      BR
# iso3                     BRA
# population          12592000
# Name: 537, dtype: object
#
#  city           Zhuzhou
# lat                NaN
# lng           113.1469
# country          China
# iso2                CN
# iso3               CHN
# population     4020800
# Name: 772, dtype: object
#
#  city           Yaoundé
# lat             3.8667
# lng                NaN
# country       Cameroon
# iso2                CM
# iso3               CMR
# population     2440462
# Name: 724, dtype: object

# %%
# fill the missing values by their country 

# Group by 'country' and fill missing values with the mean of the respective column
df['lat'] = df.groupby('country')['lat'].transform(lambda x: x.fillna(x.mean()))
df['lng'] = df.groupby('country')['lng'].transform(lambda x: x.fillna(x.mean()))
df
# Out:
#           city        lat       lng               country iso2 iso3  \
# 0          Aba   5.116700    7.3667               Nigeria   NG  NGA
# 1      Abidjan   5.316700   -4.0333         Côte d'Ivoire   CI  CIV
# 2    Abu Dhabi  24.466700   54.3667  United Arab Emirates   AE  ARE
# 3        Abuja   9.066700    7.4833               Nigeria   NG  NGA
# 4        Accra   5.550000   -0.2000                 Ghana   GH  GHA
# ..         ...        ...       ...                   ...  ...  ...
# 771  Zhumadian  32.977300  114.0253                 China   CN  CHN
# 772    Zhuzhou  32.174206  113.1469                 China   CN  CHN
# 773       Zibo  36.783100  118.0497                 China   CN  CHN
# 774     Zigong  29.349800  104.7645                 China   CN  CHN
# 775      Zunyi  27.705000  106.9336                 China   CN  CHN
#
#      population
# 0       1530000
# 1       4980000
# 2       1483000
# 3       3770000
# 4       2388000
# ..          ...
# 771     7231234
# 772     4020800
# 773     2631647
# 774     2678899
# 775     6606675
#
# [767 rows x 7 columns]

# %%
df.loc[537]
# Out:
# city          Rio de Janeiro
# lat               -14.600439
# lng                 -43.2056
# country               Brazil
# iso2                      BR
# iso3                     BRA
# population          12592000
# Name: 537, dtype: object

# %% [markdown]
# <div dir="rtl">
# <h3 align=right style="font-size: 16;line-height:100%;font-family:vazir;color:white">
# محاسبه فاصله
# </h3>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# می‌خواهیم فاصله هر یک از شهر‌ها را از تهران حساب کنیم. برای این کار از فرمول هاورسین استفاده خواهیم کرد. این فرمول بر اساس طول جغرافیایی (Logitude) و عرض جغرافیایی (Latitude)  دو نقطه در سطح یک کره، فاصله آنها را حساب می‌کند.
# فرمول محاسبه فاصله هاورسین در ادامه آورده شده است.
# خواسته ما این است که اول با توجه به فرمول هاورسین و مقادیر طول و عرض جغرافیایی تهران که از دیتافریم استخراج می‌کنید تابعی بنویسید که فاصله هر شهر را از تهران محاسبه کند و سپس با استفاده از آن تابع ستون جدیدی در دیتافریم ایجاد کنید که فاصله هر شهر از تهران را داشته باشد
# </font>
# </p>
#
# </div>

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# فرمول هاورسین:
# </font>
# </p>
#
#
#
# $\lambda_1$, $\lambda_2$ : longitudes of the two points in radians (lng)
#
# $\varphi_1$, $\varphi_2$ : the latitudes of the two points in radians (lat)
#
# $d$ : distance between two cities
#
#
# $$
# r = 6371
# $$
# $$
# a = \sin^2\left(\frac{\varphi_2-\varphi_1}{2}\right) + \cos(\varphi_1)\cos(\varphi_2)\sin^2\left(\frac{\lambda_2-\lambda_1}{2}\right)
# $$
# $$
# d = 2r \operatorname{atan2}\left(\sqrt{a}, \sqrt{1 -a}\right)
# $$
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# <code>تذکر:</code>
# دقت کنید که مقادیر طول و عرض جغرافیایی ثبت شده در دیتافریم به درجه می‌باشد و برای استفاده از رابطه فوق باید به رادیان تبدیل گردد. همچنین توجه کنید ملاک ارزیابی پاسخ شما فرمول فوق و طول و عرض جغرافیایی تهران که در همین دیتافریم درج شده، می‌باشد.
# </font>
# </p>

# %%
# distance function 
from math import radians, sin, cos, sqrt, atan2
radius = 6371

def haversine(lat1, lng1, lat2, lng2):
    """
    Calculate the great circle distance in kilometers between two points 
    on the Earth (specified in decimal degrees)
    """
    # Convert latitude and longitude from degrees to radians
    lat1, lng1, lat2, lng2 = map(radians, [lat1, lng1, lat2, lng2])

    # Haversine formula    
    a = sin((lat2 - lat1)/2)**2 + cos(lat1) * cos(lat2) * sin((lng2 - lng1)/2)**2
    distance = 2 * radius * atan2(sqrt(a), sqrt(1-a)) 
    
    return distance  # Radius of Earth in kilometers

# %%
# add a new column in DataFrame 
tehran_lat = df[df['city'] == 'Tehran'].lat
tehran_lng = df[df['city'] == 'Tehran'].lng

df['Distance_From_Tehran'] = df.apply(lambda row: haversine(tehran_lat, tehran_lng, row['lat'], row['lng']), axis=1)
df
# Out:
#           city        lat       lng               country iso2 iso3  \
# 0          Aba   5.116700    7.3667               Nigeria   NG  NGA
# 1      Abidjan   5.316700   -4.0333         Côte d'Ivoire   CI  CIV
# 2    Abu Dhabi  24.466700   54.3667  United Arab Emirates   AE  ARE
# 3        Abuja   9.066700    7.4833               Nigeria   NG  NGA
# 4        Accra   5.550000   -0.2000                 Ghana   GH  GHA
# ..         ...        ...       ...                   ...  ...  ...
# 771  Zhumadian  32.977300  114.0253                 China   CN  CHN
# 772    Zhuzhou  32.174206  113.1469                 China   CN  CHN
# 773       Zibo  36.783100  118.0497                 China   CN  CHN
# 774     Zigong  29.349800  104.7645                 China   CN  CHN
# 775      Zunyi  27.705000  106.9336                 China   CN  CHN
#
#      population  Distance_From_Tehran
# 0       1530000           5634.737243
# 1       4980000           6575.533770
# 2       1483000           1280.150009
# 3       3770000           5331.673578
# 4       2388000           6230.918394
# ..          ...                   ...
# 771     7231234           5659.546660
# 772     4020800           5616.330650
# 773     2631647           5851.598592
# 774     2678899           4993.215896
# 775     6606675           5260.416825
#
# [767 rows x 8 columns]

# %% [markdown]
# <div dir="rtl">
# <h3 align=right style="font-size: 16;line-height:100%;font-family:vazir;color:white">
# مرتب سازی
# </h3>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# شهرها را بر اساس حروف الفبا به صورت صعودی مرتب نمایید و سپس بر اساس مقدار ستون
# <code>
# lat
# </code>
# به صورت نزولی مرتب کرده
# </font>
# </p>
#
# </div>

# %%
# Sorting
df = df.sort_values(by='city').reset_index(drop=True)
df
# Out:
#           city      lat       lng               country iso2 iso3  population  \
# 0          Aba   5.1167    7.3667               Nigeria   NG  NGA     1530000
# 1      Abidjan   5.3167   -4.0333         Côte d'Ivoire   CI  CIV     4980000
# 2    Abu Dhabi  24.4667   54.3667  United Arab Emirates   AE  ARE     1483000
# 3        Abuja   9.0667    7.4833               Nigeria   NG  NGA     3770000
# 4        Accra   5.5500   -0.2000                 Ghana   GH  GHA     2388000
# ..         ...      ...       ...                   ...  ...  ...         ...
# 762     Ürümqi  43.8225   87.6125                 China   CN  CHN     4335017
# 763       Āgra  27.1800   78.0200                 India   IN  IND     1585704
# 764      İzmir  38.4200   27.1400                Turkey   TR  TUR     4320519
# 765      Ōsaka  34.6939  135.5022                 Japan   JP  JPN    15126000
# 766  Şanlıurfa  37.1583   38.7917                Turkey   TR  TUR     1985753
#
#      Distance_From_Tehran
# 0             5634.737243
# 1             6575.533770
# 2             1280.150009
# 3             5331.673578
# 4             6230.918394
# ..                    ...
# 762           3197.472953
# 763           2687.466060
# 764           2166.791444
# 765           7381.949949
# 766           1138.007632
#
# [767 rows x 8 columns]

# %%
# Sorting
df_sort_by_lat = df.sort_values(by='lat', ascending=False).reset_index(drop=True)
df_sort_by_lat
# Out:
#                  city      lat       lng      country iso2 iso3  population  \
# 0            Helsinki  60.1708   24.9375      Finland   FI  FIN     1268296
# 1    Saint Petersburg  59.9500   30.3167       Russia   RU  RUS     5384342
# 2                Oslo  59.9133   10.7389       Norway   NO  NOR     1064235
# 3           Stockholm  59.3294   18.0686       Sweden   SE  SWE     1611776
# 4                Perm  58.0139   56.2489       Russia   RU  RUS     1048005
# ..                ...      ...       ...          ...  ...  ...         ...
# 762      Buenos Aires -34.5997  -58.3819    Argentina   AR  ARG    16710000
# 763        Montevideo -34.8836  -56.1819      Uruguay   UY  URY     1719453
# 764          Adelaide -34.9275  138.6000    Australia   AU  AUS     1295714
# 765          Auckland -36.8406  174.7400  New Zealand   NZ  NZL     1346091
# 766         Melbourne -37.8142  144.9631    Australia   AU  AUS     4529500
#
#      Distance_From_Tehran
# 0             3313.155033
# 1             3092.500961
# 2             3951.965215
# 3             3559.106922
# 4             2508.209492
# ..                    ...
# 762          13774.501679
# 763          13602.347680
# 764          11959.512860
# 765          15011.664376
# 766          12613.179514
#
# [767 rows x 8 columns]

# %% [markdown]
# <div dir="rtl">
# <h3 align=right style="font-size: 16;line-height:100%;font-family:vazir;color:white">
# ذخیره سازی
# </h3>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# دیتافریم مرتب شده را بدون نمایه‌هایش (index) در فایلی به فرمت روبه‌رو ذخیره کنید
#
# <code>
# StudentNumber.csv
# </code>
# <p style=color:yellow>
# شماره دانشجویی خودتان را جایگزین StudentNumber کنید
# </p>
# </font>
# </p>
#
# </div>

# %%
# Save CSV file
df.to_csv("./results/9831322.csv", index=False)

# %% [markdown]
# <div align=center>
#     <img src="image-2.png" alt="Alt text">
# </div>
# <div align=center>
#     <p dir="rtl">3 سطر اول فایل شما باید به صورت فوق باشد</p>
# </div>

# %% [markdown]
# <div dir="rtl">
# <h3 align=right style="font-size: 16;line-height:100%;font-family:vazir;color:white">
# مصور سازی
# </h3>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# در این قسمت نموداری رسم کنید که فاصله 10 شهری که کمترین فاصله را از تهران دارند را در قالب یک bar chart نمایش دهد.
# </font>
# <br>
# نمودار خروجی خود را به فرمت روبه‌رو ذخیر کنید:
# <code> plot_1.png </code>
# </p>
#
# </div>

# %%
# 10 Nearest Cities to Tehran
closest_cities = df.sort_values(by='Distance_From_Tehran').head(10)

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(closest_cities['city'], closest_cities['Distance_From_Tehran'], color='purple')
plt.xlabel('City')
plt.ylabel('Distance from Tehran (km)')
plt.title('Top 10 Cities Closest to Tehran')
plt.xticks(rotation=45)

# Save the plot as plot_1.png
plt.savefig('./results/plot_1_1.png')

# %%
# 10 Nearest Cities to Tehran
closest_cities = df.sort_values(by='Distance_From_Tehran').iloc[1:11]

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(closest_cities['city'], closest_cities['Distance_From_Tehran'], color='purple')
plt.xlabel('City')
plt.ylabel('Distance from Tehran (km)')
plt.title('Top 10 Cities Closest to Tehran - Tehran is excluded')
plt.xticks(rotation=45)

# Save the plot as plot_1.png
plt.savefig('./results/plot_1_2.png')

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# در قسمت بعدی می‌خواهیم جمعیت 10 شهری که کمترین فاصله را با تهران دارند را رسم نمایید.
# <br>
# نمودار خروجی خود را به فرمت روبه‌رو ذخیر کنید:
# <code> plot_2.png </code>
# </font>
# </p>

# %%
# Population of the 10 Nearest Cities to Tehran
closest_cities = df.sort_values(by='Distance_From_Tehran').head(10)

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(closest_cities['city'], closest_cities['population'], color='salmon')
plt.xlabel('City')
plt.ylabel('Population')
plt.title('Population of 10 Cities Closest to Tehran')
plt.xticks(rotation=45)

# Save the plot as plot_1.png
plt.savefig('./results/plot_2_1.png')

# %%
# Population of the 10 Nearest Cities to Tehran
closest_cities = df.sort_values(by='Distance_From_Tehran').iloc[1:11]

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(closest_cities['city'], closest_cities['population'], color='salmon')
plt.xlabel('City')
plt.ylabel('Population')
plt.title('Population of 10 Cities Closest to Tehran - tehran is excluded')
plt.xticks(rotation=45)

# Save the plot as plot_1.png
plt.savefig('./results/plot_2_2.png')

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# در قسمت آخر میخواهیم نمودار Scatter ای رسم کنید که محور افقی آن Longtitude و محور عمودی آن Latitude باشد.
# </font>
# خروجی نهایی این نمودار با توجه به حجم بالای دیتاست بسیار جالب است.
#
# <br>
# نمودار خروجی خود را به فرمت روبه‌رو ذخیر کنید:
# <code> plot_3.png </code>
# </p>

# %%
# City Latitudes and Longitudes

# Assuming df is your dataframe
plt.figure(figsize=(10, 6))
plt.scatter(df['lng'], df['lat'], color='green')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Scatter Plot of Cities (Longitude vs. Latitude)')

# Save the plot as plot_3.png
plt.savefig('./results/plot_3.png')

# %% [markdown]
# <div dir="rtl">
# <h3 align=right style="font-size: 16;line-height:100%;font-family:vazir;color:green">
# بخش امتیازی
# </h3>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# هر نوع مصور سازی دیگر و یا تحلیل و کار با داده در صورتی که به فهم بهتر داده کمک کند نمره امتیازی خواهد داشت.
# </p>
#
# </div>
